# %%
#0

str1 = "パトカー"
str2 = "タクシー"

combined = ''.join([c1 + c2 for c1, c2 in zip(str1, str2)])
print(combined)
# Out:
# パタトクカシーー

# %%
string = "パタトクカシーー"

extracted = ''.join([c for i, c in enumerate(string) if ((i % 2) == 1)])
print(extracted)
# Out:
# タクシー

# %%
string = "stressed"
string[::-1]
# Out:
# 'desserts'

# %%
import re
text = "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."

num_list = re.split(r'[,.]|\s', text)
[len(s) for s in num_list if len(s)>0]
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]
